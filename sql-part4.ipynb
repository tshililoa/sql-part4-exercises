-- %% [markdown]
-- # Exercises: Complex queries
--
-- For the exercises, you are tasked with writing five queries that will help you delve deeper into BooksDB. You can choose whether you want to use a correlated subquery, a nested subquery, the UNION operator, the INTERSECT operator, or the EXCEPT operator for each one. You may not use joins or add multiple statements to the WHERE clause.
--
-- 1. Write a query that will return the number of users who rated a book above it's average rating.

-- %%
--SELECT b.average_rating
--FROM BooksDB.dbo.books AS b

SELECT COUNT(DISTINCT r.user_id) AS 'number_of_users'
FROM BooksDB.dbo.ratings AS r
WHERE r.rating  > (SELECT  b.average_rating FROM BooksDB.dbo.books AS b WHERE r.book_id = b.book_id )
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:01.222
-- <table><tr><th>number_of_users</th></tr><tr><td>19926</td></tr></table>

-- %% [markdown]
-- 2. Write a query that returns the book ids of all books that have over 1000 ratings of 1 star or over 1000 ratings of 5 stars.

-- %%
SELECT   b.book_id 
FROM BooksDB.dbo.books AS b
WHERE b.ratings_count > 1000
AND b.book_id IN (SELECT r.book_id FROM BooksDB.dbo.ratings AS r WHERE r.rating = 1 OR r. rating =5)
ORDER BY b.book_id
-- Out:
-- (812 rows affected)
-- Total execution time: 00:00:00.317
-- <table><tr><th>book_id</th></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>5</td></tr><tr><td>6</td></tr><tr><td>8</td></tr><tr><td>10</td></tr><tr><td>11</td></tr><tr><td>13</td></tr><tr><td>21</td></tr><tr><td>24</td></tr><tr><td>25</td></tr><tr><td>26</td></tr><tr><td>27</td></tr><tr><td>28</td></tr><tr><td>29</td></tr><tr><td>30</td></tr><tr><td>33</td></tr><tr><td>34</td></tr><tr><td>36</td></tr><tr><td>50</td></tr><tr><td>67</td></tr><tr><td>93</td></tr><tr><td>98</td></tr><tr><td>105</td></tr><tr><td>106</td></tr><tr><td>112</td></tr><tr><td>117</td></tr><tr><td>119</td></tr><tr><td>122</td></tr><tr><td>231</td></tr><tr><td>249</td></tr><tr><td>250</td></tr><tr><td>264</td></tr><tr><td>275</td></tr><tr><td>291</td></tr><tr><td>295</td></tr><tr><td>304</td></tr><tr><td>320</td></tr><tr><td>343</td></tr><tr><td>348</td></tr><tr><td>350</td></tr><tr><td>353</td></tr><tr><td>355</td></tr><tr><td>357</td></tr><tr><td>359</td></tr><tr><td>360</td></tr><tr><td>365</td></tr><tr><td>378</td></tr><tr><td>386</td></tr><tr><td>400</td></tr><tr><td>415</td></tr><tr><td>424</td></tr><tr><td>428</td></tr><tr><td>431</td></tr><tr><td>432</td></tr><tr><td>446</td></tr><tr><td>447</td></tr><tr><td>449</td></tr><tr><td>456</td></tr><tr><td>475</td></tr><tr><td>597
</td></tr><tr><td>2067</td></tr><tr><td>2068</td></tr><tr><td>2094</td></tr><tr><td>2095</td></tr><tr><td>2122</td></tr><tr><td>2137</td></tr><tr><td>2142</td></tr><tr><td>2152</td></tr><tr><td>2156</td></tr><tr><td>2159</td></tr><tr><td>2165</td></tr><tr><td>2175</td></tr><tr><td>2183</td></tr><tr><td>2187</td></tr><tr><td>2199</td></tr><tr><td>2203</td></tr><tr><td>2255</td></tr><tr><td>2265</td></tr><tr><td>2279</td></tr><tr><td>2368</td></tr><tr><td>2371</td></tr><tr><td>2372</td></tr><tr ...

-- %% [markdown]
-- 3. Write a query that returns the book ids of all books that have over 1000 ratings of 1 star and over 1000 ratings of 5 stars.

-- %%
SELECT TOP 10  b.book_id 
FROM BooksDB.dbo.books AS b
WHERE b.ratings_count > 1000
AND b.book_id IN (SELECT r.book_id FROM BooksDB.dbo.ratings AS r WHERE r.rating = 1 )
UNION
SELECT TOP 10  b.book_id 
FROM BooksDB.dbo.books AS b
WHERE b.ratings_count > 1000
AND b.book_id IN (SELECT r.book_id FROM BooksDB.dbo.ratings AS r WHERE r.rating = 5)
ORDER BY b.book_id
-- Out:
-- (14 rows affected)
-- Total execution time: 00:00:00.808
-- <table><tr><th>book_id</th></tr><tr><td>67</td></tr><tr><td>93</td></tr><tr><td>98</td></tr><tr><td>105</td></tr><tr><td>106</td></tr><tr><td>112</td></tr><tr><td>117</td></tr><tr><td>119</td></tr><tr><td>122</td></tr><tr><td>231</td></tr><tr><td>249</td></tr><tr><td>264</td></tr><tr><td>275</td></tr><tr><td>291</td></tr></table>

-- %% [markdown]
-- 4. Write a query that returns the book ids of books that have a language code of "en-US" and not a langugae code of "en-GB".

-- %%
SELECT TOP 10  b.book_id 
FROM BooksDB.dbo.books AS b
WHERE language_code = 'en-US'
-- Out:
-- (10 rows affected)
-- Total execution time: 00:00:00.167
-- <table><tr><th>book_id</th></tr><tr><td>41865</td></tr><tr><td>5907</td></tr><tr><td>1934</td></tr><tr><td>428263</td></tr><tr><td>113436</td></tr><tr><td>11</td></tr><tr><td>1162543</td></tr><tr><td>37435</td></tr><tr><td>1656001</td></tr><tr><td>6442769</td></tr></table>

-- %% [markdown]
-- 5. Write a query that returns the names of the tags and the tag ids for tags that were used over 100,000 times for a book.

-- %%
SELECT  t.tag_name, t.tag_id
FROM BooksDB.dbo.tags AS t
WHERE t.tag_id IN (SELECT  b.tag_id
                                    FROM BooksDB.dbo.book_tags AS b
                                    WHERE b.count > 100000)
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.200
-- <table><tr><th>tag_name</th><th>tag_id</th></tr><tr><td>to-read</td><td>30574</td></tr></table>
